# %%
import pandas as pd

# %%
data =pd.read_csv('C:\\Users\\CHIRAG\\Documents\\GitHub\\ML_Studycamp\\Projects\\dataset\\HR-Employee-Attrition.csv')
df=pd.DataFrame(data)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
df['Attrition'].value_counts(normalize=True)*100
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.nunique().sort_values()
# Out:
# EmployeeCount                  1
# Over18                         1
# StandardHours                  1
# Attrition                      2
# OverTime                       2
# PerformanceRating              2
# Gender                         2
# BusinessTravel                 3
# Department                     3
# MaritalStatus                  3
# RelationshipSatisfaction       4
# StockOptionLevel               4
# JobSatisfaction                4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
df['EmployeeCount'].unique()
# Out:
# array([1])

# %%
df['Attrition'].nunique()
# Out:
# 2

# %%
df_ml=df[['Age','Gender','MaritalStatus','Department','JobLevel','JobRole','YearsAtCompany','MonthlyIncome','PercentSalaryHike','OverTime','JobSatisfaction','WorkLifeBalance','PerformanceRating','Attrition']]
df_ml
# Out:
#       Age  Gender MaritalStatus              Department  JobLevel  \
# 0      41  Female        Single                   Sales         2
# 1      49    Male       Married  Research & Development         2
# 2      37    Male        Single  Research & Development         1
# 3      33  Female       Married  Research & Development         1
# 4      27    Male       Married  Research & Development         1
# ...   ...     ...           ...                     ...       ...
# 1465   36    Male       Married  Research & Development         2
# 1466   39    Male       Married  Research & Development         3
# 1467   27    Male       Married  Research & Development         2
# 1468   49    Male       Married                   Sales         2
# 1469   34    Male       Married  Research & Development         2
#
#                         JobRole  YearsAtCompany  MonthlyIncome  \
# 0               Sales Executive               6           5993
# ...
